# %% [markdown]
# # 奇偶数预测问题
# 首先导入torch并划分数据集

# %%
import torch

train_set, test_set = torch.utils.data.random_split(
    dataset=range(1000),
    lengths=[700, 300],
)

# %%
train_loader = torch.utils.data.DataLoader(
    dataset=train_set,
    batch_size=64,
    shuffle=True,
)
test_loader = torch.utils.data.DataLoader(
    dataset=test_set,
    batch_size=64,
    shuffle=True,
)

# %% [markdown]
# 定义三层线性层模型

# %%
class Model(torch.nn.Module):
    def __init__(self, in_dim=1, use_sin=False):
        super().__init__()
        self.use_sin = use_sin
        self.fc1 = torch.nn.Linear(in_dim, 128)
        self.fc2 = torch.nn.Linear(128, 128)
        self.fc3 = torch.nn.Linear(128, 1)

    def forward(self, x, ):
        if self.use_sin:
            x = torch.sin(x)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))
        return x

# %% [markdown]
# 使用BCEloss进行训练

# %%
NUM_EPOCHS = 1000
PRINT_ITER = 10
TEST_ITER = 10
model = Model()
opt = torch.optim.Adam(params=model.parameters(), lr=3e-4)
criterion = torch.nn.BCELoss()

for _ in range(NUM_EPOCHS):
    L = 0.
    model.train()
    for data in train_loader:
        data = data.unsqueeze(dim=1)
        data = torch.tensor(data, dtype=torch.float)
        label = data % 2
        opt.zero_grad()
        loss = criterion(model(data), label)
        loss.backward()
        opt.step()
        L += loss

    if _ % PRINT_ITER == 0:
        print("Train epoch %d, loss=%.1f" % (_, L))

    if _ % TEST_ITER == 0:
        model.eval()
        L = 0.
        for data in test_loader:
            data = data.unsqueeze(dim=1)
            data = torch.tensor(data, dtype=torch.float)
            label = data % 2
            loss = criterion(model(data), label)
            L += loss
        print("Test epoch %d, loss=%.1f" % (_, L))
# Out:
# C:\Users\86155\AppData\Local\Temp\ipykernel_10836\3069580528.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(data, dtype=torch.float)
# C:\Users\86155\AppData\Local\Temp\ipykernel_10836\3069580528.py:29: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(data, dtype=torch.float)
# Train epoch 0, loss=79.4
# Test epoch 0, loss=5.5
# Train epoch 10, loss=8.7
# Test epoch 10, loss=3.8
# Train epoch 20, loss=8.5
# Test epoch 20, loss=3.8
# Train epoch 30, loss=11.3
# Test epoch 30, loss=5.1
# Train epoch 40, loss=8.2
# Test epoch 40, loss=3.5
# Train epoch 50, loss=7.9
# Test epoch 50, loss=3.6
# Train epoch 60, loss=9.4
# Test epoch 60, loss=5.6
# Train epoch 70, loss=7.8
# Test epoch 70, loss=3.6
# Train epoch 80, loss=8.2
# Test epoch 80, loss=3.8
# Train epoch 90, loss=8.2
# Test epoch 90, loss=5.3
# Train epoch 100, loss=8.2
# Test epoch 100, loss=3.5
# Train epoch 110, loss=8.3
# Test epoch 110, loss=3.7
# Train epoch 120, loss=8.8
# Test epoch 120, loss=3.8
# Train epoch 130, loss=8.8
# Test epoch 130, loss=4.5
# Train epoch 140, loss=8.0
# Test epoch 140, loss=3.5
# Train epoch 150, loss=9.3
# Test epoch 150, loss=6.6
# Train epoch 160, loss=9.4
# Test epoch 160, loss=5.4
# Train epoch 170, loss=8.8
# Test epoch 170, loss=3.8
# Train epoch 180, loss=8.1
# Test epoch 180, loss=3.6
# Train epoch 190, loss=8.0
# Test epoch 190, loss=3.5
# Train epoch 200, loss=8.8
# Test epoch 200, loss=3.8
# Train epoch 210, loss=8.4
# Test epoch 210, loss=3.6
# Train epoch 220, loss=8.6
# Test epoch 220, loss=4.8
# Train epoch 230, loss=9.4
# Test epoch 230, loss=5.0
# Train epoch 240, loss=8.2
# Test epoch 240, loss=3.5
# Train epoch 250, loss=7.7
# Test epoch 250, loss=3.7
# Train epoch 260, loss=8.6
# Test epoch 260, loss=4.5
# Train epoch 270, loss=8.4
# Test epoch 270, loss=4.5
# Train epoch 280, loss=7.7
# Test epoch 280, loss=3.6
# Train epoch 290, loss=9.2
# Test epoch 290, loss=3.7
# Train epoch 300, loss=9.0
# Test epoch 300, loss=3.9
# Train epoch 310, loss=7.7
# Test epoch 310, loss=3.8
# Train epoch 320, loss=7.7
# Test epoch 320, loss=3.6
# Train epoch 330, loss=9.0
# Test epoch 330, loss=4.7
# Train epoch 340, loss=8.0
# Test epoch 340, loss=3.6
# Train epoch 350, loss=8.1
# Test epoch 350, loss=3.6
# Train epoch 360, loss=7.8
# Test epoch 360, loss=3.9
# Train epoch 370, loss=8.0
# Test epoch 370, loss=3.9
# Train epoch 380, loss=7.9
# Test epoch 380, loss=4.1
# Train epoch 390, loss=8.2
# Test epoch 390, loss=4.7
# Train epoch 400, loss=8.2
# Test epoch 400, loss=3.6
# Train epoch 410, loss=7.7
# Test epoch 410, loss=3.8
# Train epoch 420, loss=8.6
# Test epoch 420, loss=3.6
# Train epoch 430, loss=8.1
# Test epoch 430, loss=3.6
# Train epoch 440, loss=7.7
# Test epoch 440, loss=3.6
# Train epoch 450, loss=9.4
# Test epoch 450, loss=4.9
# Train epoch 460, loss=8.0
# Test epoch 460, loss=4.0
# Train epoch 470, loss=7.9
# Test epoch 470, loss=3.7
# Train epoch 480, loss=8.1
# Test epoch 480, loss=4.1
# Train epoch 490, loss=7.9
# Test epoch 490, loss=4.0
# Train epoch 500, loss=8.3
# Test epoch 500, loss=3.9
# Train epoch 510, loss=7.9
# Test epoch 510, loss=3.8
# Train epoch 520, loss=8.5
# Test epoch 520, loss=3.7
# Train epoch 530, loss=8.7
# Test epoch 530, loss=3.6
# Train epoch 540, loss=8.1
# Test epoch 540, loss=4.0
# Train epoch 550, loss=7.8
# Test epoch 550, loss=3.7
# Train epoch 560, loss=8.2
# Test epoch 560, loss=3.7
# Train epoch 570, loss=8.1
# Test epoch 570, loss=4.5
# Train epoch 580, loss=8.7
# Test epoch 580, loss=3.8
# Train epoch 590, loss=8.4
# Test epoch 590, loss=4.2
# Train epoch 600, loss=7.8
# Test epoch 600, loss=3.9
# Train epoch 610, loss=7.7
# Test epoch 610, loss=3.7
# Train epoch 620, loss=7.7
# Test epoch 620, loss=3.7
# Train epoch 630, loss=7.8
# Test epoch 630, loss=3.8
# Train epoch 640, loss=10.4
# Test epoch 640, loss=5.2
# Train epoch 650, loss=8.1
# Test epoch 650, loss=3.8
# Train epoch 660, loss=7.8
# Test epoch 660, loss=3.8
# Train epoch 670, loss=9.0
# Test epoch 670, loss=4.4
# Train epoch 680, loss=8.5
# Test epoch 680, loss=4.1
# Train epoch 690, loss=8.0
# Test epoch 690, loss=4.3
# Train epoch 700, loss=8.5
# Test epoch 700, loss=4.5
# Train epoch 710, loss=8.8
# Test epoch 710, loss=4.0
# Train epoch 720, loss=7.9
# Test epoch 720, loss=3.8
# Train epoch 730, loss=8.9
# Test epoch 730, loss=4.5
# Train epoch 740, loss=7.8
# Test epoch 740, loss=3.8
# Train epoch 750, loss=8.4
# Test epoch 750, loss=3.8
# Train epoch 760, loss=7.7
# Test epoch 760, loss=3.8
# Train epoch 770, loss=8.0
# Test epoch 770, loss=4.7
# Train epoch 780, loss=8.1
# Test epoch 780, loss=3.8
# Train epoch 790, loss=7.8
# Test epoch 790, loss=3.8
# Train epoch 800, loss=8.1
# Test epoch 800, loss=4.2
# Train epoch 810, loss=7.8
# Test epoch 810, loss=3.8
# Train epoch 820, loss=7.8
# Test epoch 820, loss=3.8
# Train epoch 830, loss=8.5
# Test epoch 830, loss=4.0
# Train epoch 840, loss=8.6
# Test epoch 840, loss=4.3
# Train epoch 850, loss=7.7
# Test epoch 850, loss=4.0
# Train epoch 860, loss=8.5
# Test epoch 860, loss=4.4
# Train epoch 870, loss=8.6
# Test epoch 870, loss=6.1
# Train epoch 880, loss=7.8
# Test epoch 880, loss=5.3
# Train epoch 890, loss=8.0
# Test epoch 890, loss=5.2
# Train epoch 900, loss=7.9
# Test epoch 900, loss=5.2
# Train epoch 910, loss=8.0
# Test epoch 910, loss=5.4
# Train epoch 920, loss=7.7
# Test epoch 920, loss=5.2
# Train epoch 930, loss=8.1
# Test epoch 930, loss=5.4
# Train epoch 940, loss=8.0
# Test epoch 940, loss=5.3
# Train epoch 950, loss=7.7
# Test epoch 950, loss=5.1
# Train epoch 960, loss=8.7
# Test epoch 960, loss=6.3
# Train epoch 970, loss=7.7
# Test epoch 970, loss=5.9
# Train epoch 980, loss=7.8
# Test epoch 980, loss=5.2
# Train epoch 990, loss=7.7
# Test epoch 990, loss=5.2

# %% [markdown]
# 输入数据前使用sin函数进行处理，结果本轮训练中loss变化很小

# %%
NUM_EPOCHS = 1000
PRINT_ITER = 10
TEST_ITER = 10
model = Model(use_sin=True)
opt = torch.optim.Adam(params=model.parameters(), lr=3e-4)
criterion = torch.nn.BCELoss()

for _ in range(NUM_EPOCHS):
    L = 0.
    model.train()
    for data in train_loader:
        data = data.unsqueeze(dim=1)
        data = torch.tensor(data, dtype=torch.float)
        label = data % 2
        opt.zero_grad()
        loss = criterion(model(data), label)
        loss.backward()
        opt.step()
        L += loss

    if _ % PRINT_ITER == 0:
        print("Train epoch %d, loss=%.1f" % (_, L))

    if _ % TEST_ITER == 0:
        model.eval()
        L = 0.
        for data in test_loader:
            data = data.unsqueeze(dim=1)
            data = torch.tensor(data, dtype=torch.float)
            label = data % 2
            loss = criterion(model(data), label)
            L += loss
        print("Test epoch %d, loss=%.1f" % (_, L))
# Out:
# C:\Users\86155\AppData\Local\Temp\ipykernel_10836\3795390633.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(data, dtype=torch.float)
# C:\Users\86155\AppData\Local\Temp\ipykernel_10836\3795390633.py:29: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(data, dtype=torch.float)
# Train epoch 0, loss=7.7
# Test epoch 0, loss=3.5
# Train epoch 10, loss=7.6
# Test epoch 10, loss=3.5
# Train epoch 20, loss=7.6
# Test epoch 20, loss=3.5
# Train epoch 30, loss=7.6
# Test epoch 30, loss=3.5
# Train epoch 40, loss=7.6
# Test epoch 40, loss=3.5
# Train epoch 50, loss=7.6
# Test epoch 50, loss=3.5
# Train epoch 60, loss=7.6
# Test epoch 60, loss=3.5
# Train epoch 70, loss=7.6
# Test epoch 70, loss=3.5
# Train epoch 80, loss=7.6
# Test epoch 80, loss=3.5
# Train epoch 90, loss=7.6
# Test epoch 90, loss=3.5
# Train epoch 100, loss=7.6
# Test epoch 100, loss=3.5
# Train epoch 110, loss=7.6
# Test epoch 110, loss=3.5
# Train epoch 120, loss=7.6
# Test epoch 120, loss=3.5
# Train epoch 130, loss=7.6
# Test epoch 130, loss=3.5
# Train epoch 140, loss=7.6
# Test epoch 140, loss=3.5
# Train epoch 150, loss=7.6
# Test epoch 150, loss=3.5
# Train epoch 160, loss=7.6
# Test epoch 160, loss=3.5
# Train epoch 170, loss=7.6
# Test epoch 170, loss=3.5
# Train epoch 180, loss=7.6
# Test epoch 180, loss=3.5
# Train epoch 190, loss=7.6
# Test epoch 190, loss=3.5
# Train epoch 200, loss=7.6
# Test epoch 200, loss=3.5
# Train epoch 210, loss=7.6
# Test epoch 210, loss=3.5
# Train epoch 220, loss=7.6
# Test epoch 220, loss=3.5
# Train epoch 230, loss=7.6
# Test epoch 230, loss=3.5
# Train epoch 240, loss=7.6
# Test epoch 240, loss=3.5
# Train epoch 250, loss=7.6
# Test epoch 250, loss=3.5
# Train epoch 260, loss=7.6
# Test epoch 260, loss=3.5
# Train epoch 270, loss=7.6
# Test epoch 270, loss=3.5
# Train epoch 280, loss=7.6
# Test epoch 280, loss=3.5
# Train epoch 290, loss=7.6
# Test epoch 290, loss=3.5
# Train epoch 300, loss=7.6
# Test epoch 300, loss=3.5
# Train epoch 310, loss=7.6
# Test epoch 310, loss=3.5
# Train epoch 320, loss=7.6
# Test epoch 320, loss=3.5
# Train epoch 330, loss=7.6
# Test epoch 330, loss=3.5
# Train epoch 340, loss=7.6
# Test epoch 340, loss=3.5
# Train epoch 350, loss=7.6
# Test epoch 350, loss=3.5
# Train epoch 360, loss=7.6
# Test epoch 360, loss=3.5
# Train epoch 370, loss=7.6
# Test epoch 370, loss=3.5
# Train epoch 380, loss=7.6
# Test epoch 380, loss=3.5
# Train epoch 390, loss=7.6
# Test epoch 390, loss=3.5
# Train epoch 400, loss=7.6
# Test epoch 400, loss=3.5
# Train epoch 410, loss=7.6
# Test epoch 410, loss=3.5
# Train epoch 420, loss=7.6
# Test epoch 420, loss=3.5
# Train epoch 430, loss=7.6
# Test epoch 430, loss=3.5
# Train epoch 440, loss=7.6
# Test epoch 440, loss=3.5
# Train epoch 450, loss=7.6
# Test epoch 450, loss=3.5
# Train epoch 460, loss=7.6
# Test epoch 460, loss=3.5
# Train epoch 470, loss=7.6
# Test epoch 470, loss=3.5
# Train epoch 480, loss=7.6
# Test epoch 480, loss=3.5
# Train epoch 490, loss=7.6
# Test epoch 490, loss=3.5
# Train epoch 500, loss=7.6
# Test epoch 500, loss=3.5
# Train epoch 510, loss=7.6
# Test epoch 510, loss=3.5
# Train epoch 520, loss=7.6
# Test epoch 520, loss=3.5
# Train epoch 530, loss=7.6
# Test epoch 530, loss=3.5
# Train epoch 540, loss=7.6
# Test epoch 540, loss=3.5
# Train epoch 550, loss=7.6
# Test epoch 550, loss=3.5
# Train epoch 560, loss=7.6
# Test epoch 560, loss=3.5
# Train epoch 570, loss=7.6
# Test epoch 570, loss=3.5
# Train epoch 580, loss=7.6
# Test epoch 580, loss=3.5
# Train epoch 590, loss=7.6
# Test epoch 590, loss=3.5
# Train epoch 600, loss=7.6
# Test epoch 600, loss=3.5
# Train epoch 610, loss=7.6
# Test epoch 610, loss=3.5
# Train epoch 620, loss=7.6
# Test epoch 620, loss=3.5
# Train epoch 630, loss=7.6
# Test epoch 630, loss=3.5
# Train epoch 640, loss=7.6
# Test epoch 640, loss=3.5
# Train epoch 650, loss=7.6
# Test epoch 650, loss=3.5
# Train epoch 660, loss=7.6
# Test epoch 660, loss=3.5
# Train epoch 670, loss=7.6
# Test epoch 670, loss=3.5
# Train epoch 680, loss=7.6
# Test epoch 680, loss=3.5
# Train epoch 690, loss=7.6
# Test epoch 690, loss=3.5
# Train epoch 700, loss=7.6
# Test epoch 700, loss=3.5
# Train epoch 710, loss=7.6
# Test epoch 710, loss=3.5
# Train epoch 720, loss=7.6
# Test epoch 720, loss=3.5
# Train epoch 730, loss=7.6
# Test epoch 730, loss=3.5
# Train epoch 740, loss=7.6
# Test epoch 740, loss=3.5
# Train epoch 750, loss=7.6
# Test epoch 750, loss=3.5
# Train epoch 760, loss=7.6
# Test epoch 760, loss=3.5
# Train epoch 770, loss=7.6
# Test epoch 770, loss=3.5
# Train epoch 780, loss=7.6
# Test epoch 780, loss=3.5
# Train epoch 790, loss=7.6
# Test epoch 790, loss=3.5
# Train epoch 800, loss=7.6
# Test epoch 800, loss=3.5
# Train epoch 810, loss=7.6
# Test epoch 810, loss=3.5
# Train epoch 820, loss=7.6
# Test epoch 820, loss=3.5
# Train epoch 830, loss=7.6
# Test epoch 830, loss=3.5
# Train epoch 840, loss=7.6
# Test epoch 840, loss=3.5
# Train epoch 850, loss=7.6
# Test epoch 850, loss=3.5
# Train epoch 860, loss=7.6
# Test epoch 860, loss=3.5
# Train epoch 870, loss=7.6
# Test epoch 870, loss=3.5
# Train epoch 880, loss=7.6
# Test epoch 880, loss=3.5
# Train epoch 890, loss=7.6
# Test epoch 890, loss=3.5
# Train epoch 900, loss=7.6
# Test epoch 900, loss=3.5
# Train epoch 910, loss=7.6
# Test epoch 910, loss=3.5
# Train epoch 920, loss=7.6
# Test epoch 920, loss=3.5
# Train epoch 930, loss=7.6
# Test epoch 930, loss=3.5
# Train epoch 940, loss=7.6
# Test epoch 940, loss=3.5
# Train epoch 950, loss=7.6
# Test epoch 950, loss=3.5
# Train epoch 960, loss=7.6
# Test epoch 960, loss=3.5
# Train epoch 970, loss=7.6
# Test epoch 970, loss=3.5
# Train epoch 980, loss=7.6
# Test epoch 980, loss=3.5
# Train epoch 990, loss=7.6
# Test epoch 990, loss=3.5
